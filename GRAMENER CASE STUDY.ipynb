# %% [markdown]
# # Gramener Case Study

# %%
"""
###################################################################################################################################
##  
##  Program Name        : Gramener Case Study
##
##  Description         : Using EDA, understand risk analytics in banking and financial services and understand how data is used 
##                        to minimise the risk of losing money while lending to customers.  
##
##  Author(s)           : Sunil Yousef
##  
###################################################################################################################################
"""
import importlib.util
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from scipy.stats.stats import pearsonr
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.

# %% [markdown]
# ## Data Sourcing

# %% [markdown]
# ##### Load and read loan.csv to loandf data frame using ISO-8859-1 encoding

# %%
# Load the csv file to loandf dataframe
loandf = pd.read_csv("loan.csv", sep=',', encoding = "ISO-8859-1", low_memory=False)
loandf.head(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade            ...              \
# 0   10.65%       162.87     B        B2            ...
# 1   15.27%        59.83     C        C4            ...
# 2   15.96%        84.33     C        C5            ...
# 3   13.49%       339.31     C        C1            ...
# 4   12.69%        67.79     B        B5            ...
#
#   num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                NaN                NaN            NaN               NaN
# 1                NaN                NaN            NaN               NaN
# 2                NaN                NaN            NaN               NaN
# 3                NaN                NaN            NaN               NaN
# 4                NaN                NaN            NaN               NaN
#
#   pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 0                  0.0       0.0             NaN               NaN
# 1                  0.0       0.0             NaN               NaN
# 2                  0.0       0.0             NaN               NaN
# 3                  0.0       0.0             NaN               NaN
# 4                  0.0       0.0             NaN               NaN
#
#   total_bc_limit total_il_high_credit_limit
# 0            NaN                        NaN
# 1            NaN                        NaN
# 2            NaN                        NaN
# 3            NaN                        NaN
# 4            NaN                        NaN
#
# [5 rows x 111 columns]

# %% [markdown]
# ##### Get the description of loaded csv file.

# %%
loandf.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# 50%        8975.000000    280.220000  5.900000e+04     13.400000
# 75%       14400.000000    430.780000  8.230000e+04     18.600000
# max       35000.000000   1305.190000  6.000000e+06     29.990000
#
#         delinq_2yrs  inq_last_6mths             ...              \
# count  39717.000000    39717.000000             ...
# mean       0.146512        0.869200             ...
# std        0.491812        1.070219             ...
# min        0.000000        0.000000             ...
# 25%        0.000000        0.000000             ...
# 50%        0.000000        1.000000             ...
# 75%        0.000000        1.000000             ...
# max       11.000000        8.000000             ...
#
#        num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# count                 0.0                 0.0             0.0
# mean                  NaN                 NaN             NaN
# std                   NaN                 NaN             NaN
# min                   NaN                 NaN             NaN
# 25%                   NaN                 NaN             NaN
# 50%                   NaN                 NaN             NaN
# 75%                   NaN                 NaN             NaN
# max                   NaN                 NaN             NaN
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# count               0.0          39020.000000    39678.0              0.0
# mean                NaN              0.043260        0.0              NaN
# std                 NaN              0.204324        0.0              NaN
# min                 NaN              0.000000        0.0              NaN
# 25%                 NaN              0.000000        0.0              NaN
# 50%                 NaN              0.000000        0.0              NaN
# 75%                 NaN              0.000000        0.0              NaN
# max                 NaN              2.000000        0.0              NaN
#
#        total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# count                0.0             0.0                         0.0
# mean                 NaN             NaN                         NaN
# std                  NaN             NaN                         NaN
# min                  NaN             NaN                         NaN
# 25%                  NaN             NaN                         NaN
# 50%                  NaN             NaN                         NaN
# 75%                  NaN             NaN                         NaN
# max                  NaN             NaN                         NaN
#
# [8 rows x 87 columns]

# %% [markdown]
# ##### Get the information of loaded dataset

# %%
loandf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %% [markdown]
# ## Assumptions
#
# * The variables like recoveries, total_pymnt, total_pymnt_inv, total_rec_prncp etc.. which normally get captured only after a loan is accepted, will not be available at the time of a new loan application. So these type of variables can be removed from the dataset.
# * Since bankruptcy filings, tax liens and judgments are the three kinds of public records that appears on a credit report, this information should already be captured in column pub_rec which contains derogatory public records.
# * Number of values in pub_rec_bankruptcies is greater then pub_rec, Hence we can drop column pub_rec_bankruptcies.
# * purpose and title have redundant information.
# * emp_title column has so much discrepancies in its values(e.g. The same employer name is mentioned in various formats) .Also as it has many unique values it would not give any useful insights about the pattern for loan defaulting.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ##### Get the percentage of null values for each columns

# %%
# Get the percentage of null values for each columns
na_percent = round(loandf.isnull().sum() / len(loandf.index) * 100, 2)
print("\nColumns which have null values and there percentage is \n", na_percent[na_percent > 0])
# Out:
# Columns which have null values and there percentage is
#  emp_title                           6.19
# emp_length                          2.71
# desc                               32.58
# title                               0.03
# mths_since_last_delinq             64.66
# mths_since_last_record             92.99
# revol_util                          0.13
# last_pymnt_d                        0.18
# next_pymnt_d                       97.13
# last_credit_pull_d                  0.01
# collections_12_mths_ex_med          0.14
# mths_since_last_major_derog       100.00
# annual_inc_joint                  100.00
# dti_joint                         100.00
# verification_status_joint         100.00
# tot_coll_amt                      100.00
# tot_cur_bal                       100.00
# open_acc_6m                       100.00
# open_il_6m                        100.00
# open_il_12m                       100.00
# open_il_24m                       100.00
# mths_since_rcnt_il                100.00
# total_bal_il                      100.00
# il_util                           100.00
# open_rv_12m                       100.00
# open_rv_24m                       100.00
# max_bal_bc                        100.00
# all_util                          100.00
# total_rev_hi_lim                  100.00
# inq_fi                            100.00
#                                    ...
# mo_sin_old_rev_tl_op              100.00
# mo_sin_rcnt_rev_tl_op             100.00
# mo_sin_rcnt_tl                    100.00
# mort_acc                          100.00
# mths_since_recent_bc              100.00
# mths_since_recent_bc_dlq          100.00
# mths_since_recent_inq             100.00
# mths_since_recent_revol_delinq    100.00
# num_accts_ever_120_pd             100.00
# num_actv_bc_tl                    100.00
# num_actv_rev_tl                   100.00
# num_bc_sats                       100.00
# num_bc_tl                         100.00
# num_il_tl                         100.00
# num_op_rev_tl                     100.00
# num_rev_accts                     100.00
# num_rev_tl_bal_gt_0               100.00
# num_sats                          100.00
# num_tl_120dpd_2m                  100.00
# num_tl_30dpd                      100.00
# num_tl_90g_dpd_24m                100.00
# num_tl_op_past_12m                100.00
# pct_tl_nvr_dlq                    100.00
# percent_bc_gt_75                  100.00
# pub_rec_bankruptcies                1.75
# tax_liens                           0.10
# tot_hi_cred_lim                   100.00
# total_bal_ex_mort                 100.00
# total_bc_limit                    100.00
# total_il_high_credit_limit        100.00
# Length: 68, dtype: float64

# %% [markdown]
# ##### Remove all Columns with 90% or more null values

# %%
print('Removing Columns with 90% or more zeros and NA’s.')
master_frame = pd.DataFrame(loandf.loc[:, (na_percent < 90.00)])

# After Removing
na_percent = round(master_frame.isnull().sum() / len(master_frame.index) * 100, 2)
print('After Removing Columns with 90% or more zeros and NA’s.')
print("\nColumns which have null values and there percentage is \n", na_percent[na_percent > 0])
# Out:
# Removing Columns with 90% or more zeros and NA’s.
# After Removing Columns with 90% or more zeros and NA’s.
#
# Columns which have null values and there percentage is
#  emp_title                      6.19
# emp_length                     2.71
# desc                          32.58
# title                          0.03
# mths_since_last_delinq        64.66
# revol_util                     0.13
# last_pymnt_d                   0.18
# last_credit_pull_d             0.01
# collections_12_mths_ex_med     0.14
# chargeoff_within_12_mths       0.14
# pub_rec_bankruptcies           1.75
# tax_liens                      0.10
# dtype: float64

# %% [markdown]
# ##### The column "mths_since_last_delinq" has more than 60% null values so remove this.

# %%
print("Dropping mths_since_last_delinq column as it has more than 60% null values")
try:
    master_frame.drop('mths_since_last_delinq', axis=1, inplace=True)
except:
    print('Column already dropped.')
# Out:
# Dropping mths_since_last_delinq column as it has more than 60% null values

# %% [markdown]
# ##### Remove the following Columns which does not provide any meaning for the current EDA analysis.

# %%
# Remove the following Columns which does not provide any meaning to EDA analysis. 
print('Dropping the following list of columns as these columns are not needed for the EDA analysis')

column_list = ['id', 'member_id', 'grade', 'url', 'funded_amnt', 'emp_title', 'earliest_cr_line', 'pymnt_plan', 'desc',
               'revol_bal', 'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
               'total_rec_int', 'total_rec_late_fee', 'recoveries', 'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
               'initial_list_status', 'collections_12_mths_ex_med', 'policy_code', 'collection_recovery_fee', 'inq_last_6mths',
               'tax_liens', 'delinq_amnt', 'chargeoff_within_12_mths', 'acc_now_delinq']

for column in column_list:
    print('Dropping', column, '...')
    try:
        master_frame.drop(column, axis=1, inplace=True)
    except:
        print('\tColumn already dropped...')
        continue
# Out:
# Dropping the following list of columns as these columns are not needed for the EDA analysis
# Dropping id ...
# Dropping member_id ...
# Dropping grade ...
# Dropping url ...
# Dropping funded_amnt ...
# Dropping emp_title ...
# Dropping earliest_cr_line ...
# Dropping pymnt_plan ...
# Dropping desc ...
# Dropping revol_bal ...
# Dropping total_acc ...
# Dropping out_prncp ...
# Dropping out_prncp_inv ...
# Dropping total_pymnt ...
# Dropping total_pymnt_inv ...
# Dropping total_rec_prncp ...
# Dropping total_rec_int ...
# Dropping total_rec_late_fee ...
# Dropping recoveries ...
# Dropping last_pymnt_d ...
# Dropping last_pymnt_amnt ...
# Dropping last_credit_pull_d ...
# Dropping initial_list_status ...
# Dropping collections_12_mths_ex_med ...
# Dropping policy_code ...
# Dropping collection_recovery_fee ...
# Dropping inq_last_6mths ...
# Dropping tax_liens ...
# Dropping delinq_amnt ...
# Dropping chargeoff_within_12_mths ...
# Dropping acc_now_delinq ...

# %% [markdown]
# ##### Remove redundant columns and columns with same values

# %%
# Application_type has same value this shall be removed
# i.e if any column has only one value then drop it.
print('Removing \'Application_type\' as it has same value, i.e if any column has only one value then drop it.')
try:
    print('Dropping application_type ...')
    master_frame.drop('application_type', axis=1, inplace=True)
except:
    print('\tColumn already dropped...')

# ‘purpose’ and ‘title’ has redundant information. 
# Purpose can be used as a categorical variable, so remove title column.
print('Columns \'purpose\' and \'title\' has redundant information. Purpose can be used as a categorical variable,\n',
      'So removing \'title\' column.')
try:
    print('Dropping title...')
    master_frame.drop('title', axis=1, inplace=True)
except:
    print('\tColumn already dropped...')
# Out:
# Removing 'Application_type' as it has same value, i.e if any column has only one value then drop it.
# Dropping application_type ...
# Columns 'purpose' and 'title' has redundant information. Purpose can be used as a categorical variable,
#  So removing 'title' column.
# Dropping title...

# %%
print(master_frame.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 21 columns):
# loan_amnt               39717 non-null int64
# funded_amnt_inv         39717 non-null float64
# term                    39717 non-null object
# int_rate                39717 non-null object
# installment             39717 non-null float64
# sub_grade               39717 non-null object
# emp_length              38642 non-null object
# home_ownership          39717 non-null object
# annual_inc              39717 non-null float64
# verification_status     39717 non-null object
# issue_d                 39717 non-null object
# loan_status             39717 non-null object
# purpose                 39717 non-null object
# zip_code                39717 non-null object
# addr_state              39717 non-null object
# dti                     39717 non-null float64
# delinq_2yrs             39717 non-null int64
# open_acc                39717 non-null int64
# pub_rec                 39717 non-null int64
# revol_util              39667 non-null object
# pub_rec_bankruptcies    39020 non-null float64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 6.4+ MB
# None

# %% [markdown]
# ##### Convert Dates to python datetime object.

# %%
# Convert dates to python datetime object.
print("Initial type", type(master_frame["issue_d"][0]))
master_frame["issue_d"] = pd.to_datetime(master_frame["issue_d"], format="%b-%y")
print("Type changed to", type(master_frame["issue_d"][0]))
# Out:
# Initial type <class 'str'>
# Type changed to <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# ##### Round to 2 decimal places

# %%
# funded_amnt_inv, installment Round to 2 decimal places.

master_frame["funded_amnt_inv"] = round(master_frame["funded_amnt_inv"], 2)
print("After rounding to 2 decimal places...\n", master_frame["funded_amnt_inv"][0:2])

master_frame["installment"] = round(master_frame["installment"], 2)
print("\nAfter rounding to 2 decimal places...\n", master_frame["installment"][0:2])
# Out:
# After rounding to 2 decimal places...
#  0    4975.0
# 1    2500.0
# Name: funded_amnt_inv, dtype: float64
#
# After rounding to 2 decimal places...
#  0    162.87
# 1     59.83
# Name: installment, dtype: float64

# %% [markdown]
# ##### Strip 'Months' from ‘Term’ Column.

# %%
# Strip 'Months' from ‘Term’ Column.
master_frame["term"] = master_frame["term"].str.replace(" months", "").astype("int64")
master_frame["term"][0:5]
# Out:
# 0    36
# 1    60
# 2    36
# 3    36
# 4    60
# Name: term, dtype: int64

# %% [markdown]
# ##### Strip '%' from ‘int_rate’ Column.

# %%
# Strip '%' from ‘int_rate’ Column.
master_frame["int_rate"] = master_frame["int_rate"].str.replace("%", "").astype("float64")

# round to 2 decimal places
master_frame['int_rate'] = round(master_frame['int_rate'], 2)
print("\nAfter rounding to 2 decimal places...\n", master_frame["int_rate"][0:2])
# Out:
# After rounding to 2 decimal places...
#  0    10.65
# 1    15.27
# Name: int_rate, dtype: float64

# %% [markdown]
# ##### Strip '%' from ‘revol_util’ Column.

# %%
# Strip '%' from ‘revol_util’ Column.
master_frame["revol_util"] = master_frame["revol_util"].str.replace("%", "").astype("float64")

# round to 2 decimal places
master_frame['revol_util'] = round(master_frame['revol_util'], 2)
print("\nAfter rounding to 2 decimal places...\n", master_frame["revol_util"][0:2])
# Out:
# After rounding to 2 decimal places...
#  0    83.7
# 1     9.4
# Name: revol_util, dtype: float64

# %% [markdown]
# ##### Column emp_length replace '< 1' with 0 and strip the sub string '+' and ‘years’ .

# %%
# Column emp_length has substring '+', '<', ‘years’ strip this.
print('\nRemoving < 1 from emp_length...')
master_frame["emp_length"] = master_frame["emp_length"].str.replace("< 1", "0")
print('\nRemoving \'+\', and \'years\' from emp_length...')
intab = "+years"
outtab = "      "
trantab = str.maketrans(intab, outtab)
master_frame["emp_length"] = master_frame["emp_length"].str.translate(trantab).astype("float64")
master_frame["emp_length"][0:5]
# Out:
# Removing < 1 from emp_length...
#
# Removing '+', and 'years' from emp_length...
# 0    10.0
# 1     0.0
# 2    10.0
# 3    10.0
# 4     1.0
# Name: emp_length, dtype: float64

# %% [markdown]
# ##### impute employee length with mean

# %%
# impute employee length with mean
master_frame.emp_length.fillna(master_frame.emp_length.mean(),inplace = True)

# round to 2 decimal places
master_frame['emp_length'] = round(master_frame['emp_length'], 2)
print("\nAfter rounding to 2 decimal places...\n", master_frame["emp_length"][0:5])
# Out:
# After rounding to 2 decimal places...
#  0    10.0
# 1     0.0
# 2    10.0
# 3    10.0
# 4     1.0
# Name: emp_length, dtype: float64

# %% [markdown]
# ##### Check the home_ownership column and perform imputation

# %%
# Check the home_ownership column
print(master_frame["home_ownership"].unique())
print(master_frame["home_ownership"].value_counts())
# Out:
# ['RENT' 'OWN' 'MORTGAGE' 'OTHER' 'NONE']
# RENT        18899
# MORTGAGE    17659
# OWN          3058
# OTHER          98
# NONE            3
# Name: home_ownership, dtype: int64

# %% [markdown]
# ##### Remove 3 rows which has “NONE” as the value in “home_ownership” column as NONE is an invalid category value for home_ownership

# %%
# Remove rows which has “NONE” as the value in “home_ownership” column.
if any("NONE" in item for item in master_frame["home_ownership"]):
    master_frame = master_frame[master_frame['home_ownership'] != 'NONE']
print("\nAfter removing 3 rows which has “NONE” as the value in “home_ownership” column....")
print(master_frame["home_ownership"].unique())
print(master_frame["home_ownership"].value_counts())
# Out:
# After removing 3 rows which has “NONE” as the value in “home_ownership” column....
# ['RENT' 'OWN' 'MORTGAGE' 'OTHER']
# RENT        18899
# MORTGAGE    17659
# OWN          3058
# OTHER          98
# Name: home_ownership, dtype: int64

# %% [markdown]
# ##### Remove 'xx' from 'zip_code'

# %%
master_frame["zip_code"] = master_frame["zip_code"].str.replace('xx', '')
master_frame["zip_code"][0:5]
# Out:
# 0    860
# 1    309
# 2    606
# 3    917
# 4    972
# Name: zip_code, dtype: object

# %% [markdown]
# ##### Create Address column by combining values in ‘zip_code’ and 'addr_state'

# %%
# Combine ‘zip_code’ and 'addr_state' to one column as 'address'
master_frame["address"] = master_frame["addr_state"].astype(str) + "," + master_frame["zip_code"].astype(str)
master_frame["address"] [0:5]
# Out:
# 0    AZ,860
# 1    GA,309
# 2    IL,606
# 3    CA,917
# 4    OR,972
# Name: address, dtype: object

# %% [markdown]
# ##### After data cleaning check which all columns have null values and and whats the percentage

# %%
na_percent = round(master_frame.isnull().sum() / len(master_frame.index) * 100, 2)
print('\nAfter data cleaning, The columns with null values and the percentge of null values in these columns ...\n')
print(na_percent[na_percent > 0])

print("These columns will be imputed/removed at the time of univariate analyis..")
# Out:
# After data cleaning, The columns with null values and the percentge of null values in these columns ...
#
# revol_util              0.13
# pub_rec_bankruptcies    1.75
# dtype: float64
# These columns will be imputed/removed at the time of univariate analyis..

# %% [markdown]
# ##### Finally check how many columns we have now.

# %%
print('Final list of Columns after data cleaning.. \n', master_frame.columns)
print('Total Number of Columns = ', len(master_frame.columns))
# Out:
# Final list of Columns after data cleaning..
#  Index(['loan_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment',
#        'sub_grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'open_acc', 'pub_rec', 'revol_util',
#        'pub_rec_bankruptcies', 'address'],
#       dtype='object')
# Total Number of Columns =  22

# %% [markdown]
# Data cleaning is completed, now we can proceed with the Univariate analysis

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# ##### Gather data for Meta Data Description

# %%
print(master_frame.info(), '\n\n')
master_frame.describe(include = 'all').T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39714 entries, 0 to 39716
# Data columns (total 22 columns):
# loan_amnt               39714 non-null int64
# funded_amnt_inv         39714 non-null float64
# term                    39714 non-null int64
# int_rate                39714 non-null float64
# installment             39714 non-null float64
# sub_grade               39714 non-null object
# emp_length              39714 non-null float64
# home_ownership          39714 non-null object
# annual_inc              39714 non-null float64
# verification_status     39714 non-null object
# issue_d                 39714 non-null datetime64[ns]
# loan_status             39714 non-null object
# purpose                 39714 non-null object
# zip_code                39714 non-null object
# addr_state              39714 non-null object
# dti                     39714 non-null float64
# delinq_2yrs             39714 non-null int64
# open_acc                39714 non-null int64
# pub_rec                 39714 non-null int64
# revol_util              39664 non-null float64
# pub_rec_bankruptcies    39020 non-null float64
# address                 39714 non-null object
# dtypes: datetime64[ns](1), float64(8), int64(5), object(8)
# memory usage: 7.0+ MB
# None
#                       count unique                  top   freq  \
# loan_amnt             39714    NaN                  NaN    NaN
# funded_amnt_inv       39714    NaN                  NaN    NaN
# term                  39714    NaN                  NaN    NaN
# int_rate              39714    NaN                  NaN    NaN
# installment           39714    NaN                  NaN    NaN
# sub_grade             39714     35                   B3   2917
# emp_length            39714    NaN                  NaN    NaN
# home_ownership        39714      4                 RENT  18899
# annual_inc            39714    NaN                  NaN    NaN
# verification_status   39714      3         Not Verified  16918
# issue_d               39714     55  2011-12-01 00:00:00   2260
# loan_status           39714      3           Fully Paid  32947
# purpose               39714     14   debt_consolidation  18640
# zip_code              39714    823                  100    597
# addr_state            39714     50                   CA   7098
# dti                   39714    NaN                  NaN    NaN
# delinq_2yrs           39714    NaN                  NaN    NaN
# open_acc              39714    NaN                  NaN    NaN
# pub_rec               39714    NaN                  NaN    NaN
# revol_util            39664    NaN                  NaN    NaN
# pub_rec_bankruptcies  39020    NaN                  NaN    NaN
# address               39714    897               NY,100    597
#
#                                     first                 last       mean  \
# loan_amnt                             NaN                  NaN    11219.9
# funded_amnt_inv                       NaN                  NaN    10398.1
# term                                  NaN                  NaN    42.4185
# int_rate                              NaN                  NaN    12.0214
# installment                           NaN                  NaN    324.573
# sub_grade                             NaN                  NaN        NaN
# emp_length                            NaN                  NaN    4.97361
# home_ownership                        NaN                  NaN        NaN
# annual_inc                            NaN                  NaN      68968
# verification_status                   NaN                  NaN        NaN
# issue_d               2007-06-01 00:00:00  2011-12-01 00:00:00        NaN
# loan_status                           NaN                  NaN        NaN
# purpose                               NaN                  NaN        NaN
# zip_code                              NaN                  NaN        NaN
# addr_state                            NaN                  NaN        NaN
# dti                                   NaN                  NaN    13.3152
# delinq_2yrs                           NaN                  NaN   0.146523
# open_acc                              NaN                  NaN    9.29458
# pub_rec                               NaN                  NaN  0.0550687
# revol_util                            NaN                  NaN    48.8349
# pub_rec_bankruptcies                  NaN                  NaN  0.0432599
# address                               NaN                  NaN        NaN
#
#                            std    min      25%     50%     75%      max
# loan_amnt              7456.74    500     5500   10000   15000    35000
# funded_amnt_inv        7128.31      0     5000    8975   14400    35000
# term                   10.6231     36       36      36      60       60
# int_rate               3.72485   5.42     9.25   11.86   14.59    24.59
# installment            208.877  15.69  167.032  280.23  430.78  1305.19
# sub_grade                  NaN    NaN      NaN     NaN     NaN      NaN
# emp_length             3.51399      0        2    4.97       9       10
# home_ownership             NaN    NaN      NaN     NaN     NaN      NaN
# annual_inc               63795   4000  40404.5   59000   82299    6e+06
# verification_status        NaN    NaN      NaN     NaN     NaN      NaN
# issue_d                    NaN    NaN      NaN     NaN     NaN      NaN
# loan_status                NaN    NaN      NaN     NaN     NaN      NaN
# purpose                    NaN    NaN      NaN     NaN     NaN      NaN
# zip_code                   NaN    NaN      NaN     NaN     NaN      NaN
# addr_state                 NaN    NaN      NaN     NaN     NaN      NaN
# dti                    6.67871      0   8.1725    13.4    18.6    29.99
# delinq_2yrs           0.491828      0        0       0       0       11
# open_acc               4.40039      2        6       9      12       44
# pub_rec               0.237208      0        0       0       0        4
# revol_util              28.332      0     25.4    49.3    72.4     99.9
# pub_rec_bankruptcies  0.204324      0        0       0       0        2
# address                    NaN    NaN      NaN     NaN     NaN      NaN

# %% [markdown]
# ###### Function to print values on top of the bars in a plot

# %%
def show_values_on_bars(axs):
    def _show_on_single_plot(ax):        
        for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height()
            value = '{:.0f}'.format(p.get_height())
            ax.text(_x, _y, value, ha="center") 

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# %% [markdown]
# ###### Function to show a bar chart

# %%
def draw_bar_chart(df, x, y, width, height, title='', xlabel='', ylabel='', legend=None, message='', showBarVals=False):
    # Restore the rc params from Matplotlib’s internal defaults.
    plt.rcdefaults() 
    
    # Set figure size
    plt.figure(figsize=(width, height))
    
    # Plot bar chart of data frame 
    ax = sns.barplot(x=x, y=y, data=df)
    
    if showBarVals == True:
        show_values_on_bars(ax)
    
    if xlabel.strip():
        plt.xlabel(xlabel)
    
    if ylabel.strip():    
        plt.ylabel(ylabel)
    
    if legend is not None:
        plt.legend(legend)
    
    if title.strip():
        plt.title(title)
        
    plt.show()
    
    if message.strip():
        print(message)

# %% [markdown]
# ###### Function to draw barchart subplot

# %%
def draw_bar_chart_subplot(df, x, y, title='', xlabel='', ylabel='',
                           legend=None, message='', showBarVals=False, show=False,
                           subplot_arg1=2, subplot_arg2=2, subplot_arg3=1):

    plt.subplot(subplot_arg1, subplot_arg2, subplot_arg3)
    
    # Plot bar chart of data frame 
    ax = sns.barplot(x=x, y=y, data=df)
    
    if showBarVals == True:
        show_values_on_bars(ax)
    
    if xlabel.strip():
        plt.xlabel(xlabel)
    
    if ylabel.strip():    
        plt.ylabel(ylabel)
    
    if legend is not None:
        plt.legend(legend)
    
    if title.strip():
        plt.title(title)
    
    if show == True:
        plt.show()
    
    if message.strip():
        print(message)

# %% [markdown]
# ##### Analysis of loans Issued per year

# %%
#------------------------------------------------------------------
# The variable issue_d is an Ordered Categorical variable.
#------------------------------------------------------------------

# Plot year wise bar chart of issue_d column 
yearwise_loans_issued = master_frame.groupby(master_frame.issue_d.dt.year).size().reset_index(name='Frequency')
draw_bar_chart(yearwise_loans_issued, "issue_d", "Frequency", 10, 6,
               'Year wise count of issued loans',
               'Years', 'Frequency', yearwise_loans_issued['issue_d'],
               'Inference: The Number of issued loans increases year by year.',
              True)

#percentage increase per year
current = previous = percentage_incr = 0.0
index = 0
for numloans in yearwise_loans_issued.Frequency:
    if current == 0.0:
        current = numloans
        previous = numloans
    else:
        previous = current
        current = numloans
    
    if previous != 0:
        percentage_incr = (current - previous) / previous * 100.0 
    elif current != 0 :
        percentage_incr = float("inf") * abs(current) / current 
    else:
        percentage_incr = 0.0
    print('\tPercentage increase for year', yearwise_loans_issued.issue_d[index], '=', round(percentage_incr), '%')
    index += 1 

# Restore the rc params from Matplotlib’s internal defaults.
plt.rcdefaults() 

# Set figure size
plt.figure(figsize=(15, 10))
    
# Plot 2007 month wise bar chart of issue_d column
loans_issued_2007 = master_frame[master_frame.issue_d.dt.year == 2007].groupby([master_frame.issue_d.dt.month]).size().reset_index(name='Frequency')
loans_issued_2007['Months'] = loans_issued_2007.issue_d.apply(lambda x: datetime.date(1900, x, 1).strftime('%b'))

draw_bar_chart_subplot(loans_issued_2007, 'Months', 'Frequency',
              '2007, Month wise count of issued loans', 'Months', 'Frequency',
              None, '', True, False, 2, 2, 1)

# Plot 2011 month wise bar chart of issue_d column
loans_issued_2011 = master_frame[master_frame.issue_d.dt.year == 2011].groupby([master_frame.issue_d.dt.month]).size().reset_index(name='Frequency')
loans_issued_2011['Months'] = loans_issued_2011.issue_d.apply(lambda x: datetime.date(1900, x, 1).strftime('%b'))

draw_bar_chart_subplot(loans_issued_2011, "Months", "Frequency",
                      '2011, Month wise count of issued loans', 'Months', 'Frequency',
                      None, '', True, True, 2, 2, 2)
# Out:
# Inference: The Number of issued loans increases year by year.
# 	Percentage increase for year 2007 = 0 %
# 	Percentage increase for year 2008 = 527 %
# 	Percentage increase for year 2009 = 202 %
# 	Percentage increase for year 2010 = 145 %
# 	Percentage increase for year 2011 = 88 %

# %% [markdown]
# ###### Analysis of Debt-To-Income Ratio(dti)

# %%
# Debt-To-Income Ratio(dti) is the percentage of a consumer's monthly gross income that goes 
# toward paying debts excluding mortgage and the requested LC loan

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
ax = sns.boxplot(y='dti', data=master_frame, palette='terrain_r')
plt.ylabel('DTI Ratio')
plt.title('Debt To Income Ratio')

#Frequency Chart 
dti = master_frame['dti']
legend = ['dti']
plt.subplot(2,2,2)
plt.hist([dti], color=['yellowgreen'], bins=6, rwidth=0.9)
plt.xlabel("Debt-To-Income Ratio")
plt.ylabel("Frequency")
plt.legend(legend)
plt.xticks(np.arange(min(dti), max(dti)+5, 5))
plt.title('Frequency of Debt-To-Income Ratio')
plt.show()

print('Inference: \n\tdti values are equally distributed along the median between 25-75 percentile with max value,',
      '\n\tApproximately at 30, minimum at 0 and maximum borrowers given loan having DTI value between 10-15% \n')
# Out:
# Inference:
# 	dti values are equally distributed along the median between 25-75 percentile with max value,
# 	Approximately at 30, minimum at 0 and maximum borrowers given loan having DTI value between 10-15%

# %% [markdown]
# ###### Analysis of Delinquency in past 2 Years(delinq_2yrs)

# %%
# Delinquency in past 2 Years(delinq_2yrs) is The number of 30+ days past-due incidences of delinquency
# ( failure to make a required payment )in the borrower's credit file for the past 2 years

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
ax = sns.boxplot(y='delinq_2yrs', data=master_frame, palette='viridis')
plt.ylabel('Delinquency in last 2 years')
plt.title('Delinquency in last 2 years')

#Frequency Chart 
delinq_2yrs_values = pd.DataFrame(master_frame['delinq_2yrs'].value_counts())
plt.subplot(2,2,2)
ax = sns.barplot(x=delinq_2yrs_values.index, y="delinq_2yrs", data=delinq_2yrs_values)
show_values_on_bars(ax)
plt.xlabel("Number of Delinquency in last 2 years")
plt.ylabel("Frequency")
plt.title('Frequency of Delinquency in last 2 years for borrowers')
plt.show()

print('Inference:\n\tMost of the delinq_2yrs values are 0 and hence highest frequency is for value 0.',
      '\n\tThere are some outliers and the max value is 11.\n')
# Out:
# Inference:
# 	Most of the delinq_2yrs values are 0 and hence highest frequency is for value 0.
# 	There are some outliers and the max value is 11.

# %% [markdown]
# ##### Analysis of Number of open credit lines in the borrower's credit file(open_acc)

# %%
# Number of open credit lines in the borrower's credit file(open_acc)

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))

plt.subplot(2,2,1)
sns.boxplot(y=master_frame['open_acc'])
plt.ylabel('Open Credit Line')
plt.title('Number of Open Credit Line')

#Frequency Chart 
open_acc_values = pd.DataFrame(master_frame['open_acc'].value_counts())
plt.subplot(2,2,2)
ax = sns.barplot(x=open_acc_values.index, y="open_acc", data=open_acc_values)
show_values_on_bars(ax)
plt.xlabel("Number of Open Credit Lines")
plt.ylabel("Frequency")
plt.title('Frequency of Open Credit Lines')
plt.xticks(rotation=60)
plt.show()

print('Inference:\n\topen_acc values seems equally distributed along the median(9) for 25-75 percentile with some outliers.\n')
# Out:
# Inference:
# 	open_acc values seems equally distributed along the median(9) for 25-75 percentile with some outliers.

# %% [markdown]
# ##### Analysis of Number of derogatory public records(pub_rec)

# %%
# Number of derogatory public records(pub_rec)
# Public records and collections are derogatory items in credit report because they all reflect financial obligations
# that were not paid as agreed

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))

plt.subplot(2,2,1)
sns.boxplot(y=master_frame['pub_rec'])
plt.ylabel('Derogatory Public Records')
plt.title('Derogatory Public Records')

#Frequency Chart 
pub_rec_values = pd.DataFrame(master_frame['pub_rec'].value_counts())
plt.subplot(2,2,2)
ax = sns.barplot(x=pub_rec_values.index, y="pub_rec", data=pub_rec_values)
show_values_on_bars(ax)
plt.xlabel("Number of Derogatory Public Records")
plt.ylabel("Frequency")
plt.title('Frequency of Derogatory Public Records')
plt.show()

print('Inference: Most of the pub_rec values are 0.There are outliers in the  column and the max value is 4. \n')
# Out:
# Inference: Most of the pub_rec values are 0.There are outliers in the  column and the max value is 4.

# %% [markdown]
# ##### Analysis of Number of public record bankruptcies (pub_rec_bankruptcies)

# %%
# Number of public record bankruptcies (pub_rec_bankruptcies)
# Since There are three kinds of public records that appear on a credit report: bankruptcy filings, tax liens and judgments
# So this informtation should already be captured in column pub_rec which contains derogatory public records

try:
    print("Number of values in pub_rec_bankruptcies greater then pub_rec :",
          (master_frame.pub_rec < master_frame.pub_rec_bankruptcies).sum())

    print('Since There are three kinds of public records that appear on a credit report:',
          '\n\tbankruptcy filings, tax liens and judgments',
          '\nSince public record bankruptcies informtation is already captured in column pub_rec',
          'which contains derogatory public records. \nWe can drop column pub_rec_bankruptcies.')

    # Hence we can drop column pub_rec_bankruptcies

    print('\nDropping pub_rec_bankruptcies column...')
    master_frame.drop('pub_rec_bankruptcies', axis=1, inplace=True)
except:
    print('Column pub_rec_bankruptcies already dropped...\n')

master_frame.info()
# Out:
# Number of values in pub_rec_bankruptcies greater then pub_rec : 0
# Since There are three kinds of public records that appear on a credit report:
# 	bankruptcy filings, tax liens and judgments
# Since public record bankruptcies informtation is already captured in column pub_rec which contains derogatory public records.
# We can drop column pub_rec_bankruptcies.
#
# Dropping pub_rec_bankruptcies column...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39714 entries, 0 to 39716
# Data columns (total 21 columns):
# loan_amnt              39714 non-null int64
# funded_amnt_inv        39714 non-null float64
# term                   39714 non-null int64
# int_rate               39714 non-null float64
# installment            39714 non-null float64
# sub_grade              39714 non-null object
# emp_length             39714 non-null float64
# home_ownership         39714 non-null object
# annual_inc             39714 non-null float64
# verification_status    39714 non-null object
# issue_d                39714 non-null datetime64[ns]
# loan_status            39714 non-null object
# purpose                39714 non-null object
# zip_code               39714 non-null object
# addr_state             39714 non-null object
# dti                    39714 non-null float64
# delinq_2yrs            39714 non-null int64
# open_acc               39714 non-null int64
# pub_rec                39714 non-null int64
# revol_util             39664 non-null float64
# address                39714 non-null object
# dtypes: datetime64[ns](1), float64(7), int64(5), object(8)
# memory usage: 7.9+ MB

# %% [markdown]
# ##### Imputing missing values with median for Revolving line utilization rate(revol_util)

# %%
# revol_util is the Percentage of credit the borrower is using relative to all available revolving credit.

# Check how many null values are there
print('\nNo: of null Values in \'revol_util\'',
      master_frame.revol_util.isnull().sum())

# There are 50 null values in revol_util check the description now
print(master_frame.revol_util.describe())

print('Both Mean(', round(master_frame.revol_util.mean(), 2), ') and Median(', master_frame.revol_util.median(),
      ') values are close , imputing missing values with median...')
master_frame.loc[master_frame.revol_util.isnull(),'revol_util'] =  master_frame.revol_util.median()
# Out:
# No: of null Values in 'revol_util' 50
# count    39664.000000
# mean        48.834875
# std         28.331964
# min          0.000000
# 25%         25.400000
# 50%         49.300000
# 75%         72.400000
# max         99.900000
# Name: revol_util, dtype: float64
# Both Mean( 48.83 ) and Median( 49.3 ) values are close , imputing missing values with median...

# %% [markdown]
# ##### Analysis of Revolving line utilization rate(revol_util)

# %%
#Revolving line utilization rate(revol_util)

# Ploting revo_util column
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.boxplot(y=master_frame['revol_util'], palette='viridis')
plt.ylabel('Revolving line utilization rate')
plt.title('Revolving line utilization rate')

#Frequency Chart
revol_util = master_frame['revol_util']
legend = ['revol_util']
plt.subplot(2,2,2)
plt.hist([revol_util], color = "skyblue", ec="skyblue", bins=10, rwidth=0.75)
plt.xlabel("Revolving line utilization rate")
plt.ylabel("Frequency ")
plt.xticks(np.arange(min(revol_util), max(revol_util)+10, 10))
plt.legend(legend)
plt.title('Frequency of Revolving line utilization rate')
plt.show()

print('Inference:\n\t\'revol_util\' values are equally distributed along the median between 25-75 percentile',
      'with max value near 100,\n'
      '\tand maximum borrowers having revolving credit utilisation rate in between 0-10%.')
# Out:
# Inference:
# 	'revol_util' values are equally distributed along the median between 25-75 percentile with max value near 100,
# 	and maximum borrowers having revolving credit utilisation rate in between 0-10%.

# %% [markdown]
# ##### Analysis of quantitative variable loan_amnt

# %%
#-------------------------------------------------------------------
# The Variable loan_amnt quantitative variables
#-------------------------------------------------------------------

print('\nloan amount')
print('\tMean =',  master_frame.loan_amnt.mean())
print('\tMedian =',  master_frame.loan_amnt.median())
print('\tMode =',  master_frame.loan_amnt.mode())

# Plotting the distribution plot of loan_amnt to visualise their distribution
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.boxplot(y=master_frame['loan_amnt'], palette='viridis')
plt.ylabel('Loan Amount')
plt.title('Loan Amount')

#Frequency Chart
loan_amnt = master_frame['loan_amnt']
legend = ['loan_amnt']
plt.subplot(2,2,2)
plt.hist([loan_amnt], color = "skyblue", ec="skyblue", bins=10, rwidth=0.95)
plt.xlabel("Loan Amount")
plt.ylabel("Frequency ")
plt.xticks(np.arange(min(loan_amnt), max(loan_amnt)+3500, 3500), rotation=60)
plt.legend(legend)
plt.title('Frequency of Loan Amount')
plt.show()

print('Inference:\n\tThe \'Loan Amount\' most frequently taken is between $4000 to $7500.',
      'But there are clearly some outliers above 98 percentile.')
# Out:
# loan amount
# 	Mean = 11219.868308405097
# 	Median = 10000.0
# 	Mode = 0    10000
# dtype: int64
# Inference:
# 	The 'Loan Amount' most frequently taken is between $4000 to $7500. But there are clearly some outliers above 98 percentile.

# %% [markdown]
# ###### Analysis of quantitative variable funded_amnt_inv

# %%
print('Mean of funded_amnt_inv = ', round(master_frame.funded_amnt_inv.mean(), 2))
print('Median of funded_amnt_inv = ', master_frame.funded_amnt_inv.median())
print('Mode of funded_amnt_inv = ', master_frame.funded_amnt_inv.mode())

# Plotting the distribution plot of funded_amnt_inv to visualise their distribution
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.boxplot(y=master_frame['funded_amnt_inv'], palette='viridis')
plt.ylabel('Funded Amount')
plt.title('Funded Amount')

#Frequency Chart
funded_amnt_inv = master_frame['funded_amnt_inv']
legend = ['funded_amnt_inv']
plt.subplot(2,2,2)
plt.hist([funded_amnt_inv], color = "skyblue", ec="skyblue", bins=10, rwidth=0.95)
plt.xlabel("Funded Amount")
plt.ylabel("Frequency ")
plt.xticks(np.arange(min(funded_amnt_inv), max(funded_amnt_inv)+3500, 3500), rotation=60)
plt.legend(legend)
plt.title('Frequency of Funded Amount by investors')
plt.show()

print('Inference:\n\tFrom the \'Funded Amount investors\' most frequently invested is between $3500 to $7000 .',
      'But there are clearly some outliers above 98 percentile.')
# Out:
# Mean of funded_amnt_inv =  10398.11
# Median of funded_amnt_inv =  8975.0
# Mode of funded_amnt_inv =  0    5000.0
# dtype: float64
# Inference:
# 	From the 'Funded Amount investors' most frequently invested is between $3500 to $7000 . But there are clearly some outliers above 98 percentile.

# %% [markdown]
# ###### Analysis of quantitative variable int_rate

# %%
print('Mean of int_rate = ', round(master_frame.int_rate.mean(), 2))
print('Median of int_rate = ', master_frame.int_rate.median())
print('Mode of int_rate = ', master_frame.int_rate.mode())

# Plotting the distribution plot of int_rate to visualise their distribution
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.boxplot(y=master_frame['int_rate'], palette='viridis')
plt.ylabel('Interest rate')
plt.title('Interest rate')

#Frequency Chart
int_rate = master_frame['int_rate']
legend = ['int_rate']
plt.subplot(2,2,2)
plt.hist([int_rate], color = "skyblue", ec="skyblue", bins=15, rwidth=0.80)
plt.xlabel("Interest rate")
plt.ylabel("Frequency ")
plt.xticks(np.arange(min(int_rate), max(int_rate)+1.3, 1.3), rotation=60)
plt.legend(legend)
plt.title('Frequency of Interest rate of each loans.')
plt.show()

print('Inference:\n\tFrom the \'Interest rate\' most frequent Interest rate is between 10.6% to 11.9% .',
      'But there are clearly some outliers above 98 percentile.')
# Out:
# Mean of int_rate =  12.02
# Median of int_rate =  11.86
# Mode of int_rate =  0    10.99
# dtype: float64
# Inference:
# 	From the 'Interest rate' most frequent Interest rate is between 10.6% to 11.9% . But there are clearly some outliers above 98 percentile.

# %% [markdown]
# ##### Analysis of purpose for taking loan given by the borrower

# %%
#-------------------------------------------------------------------
# The Variable purpose is an Unordered Categorical
#-------------------------------------------------------------------

# Plot purpose for taking loan in a horizontal bar chart 
purpose = pd.DataFrame(master_frame['purpose'].value_counts())
draw_bar_chart(purpose, 'purpose', purpose.index, 8, 3,
               'Frequency of purpose mentioned by borrower', 'Frequency', 'Purpose',
               None, 'Inference: Most of the loans are taken for debt Consolidation.\n',
               False)
# Out:
# Inference: Most of the loans are taken for debt Consolidation.

# %% [markdown]
# ###### Analysis of term column

# %%
print('The unique values in term column are, ', master_frame['term'].unique())
terms = master_frame['term']

legend = ['term']
plt.hist([terms], bins=2, rwidth=0.90, color='teal')
plt.xlabel("Terms")
plt.ylabel("Frequency")
plt.xticks(terms.unique())
plt.legend(legend)
plt.title('Term of loans')
plt.show()

print('Inference:\n\tThe most frequent term for loans is 36 months.')
# Out:
# The unique values in term column are,  [36 60]
# Inference:
# 	The most frequent term for loans is 36 months.

# %% [markdown]
# ###### Analysis of installment

# %%
print(master_frame['installment'].describe(percentiles=[0.75, 0.80, 0.85, 0.90, 0.95, 1]))

# Plotting the distribution plot of installment to visualise their distribution
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.boxplot(y=master_frame['installment'], palette='viridis')
plt.ylabel('installment')
plt.title('installment')

#Frequency Chart
installment = master_frame['installment']
legend = ['installment']
plt.subplot(2,2,2)
plt.hist([installment], color = "skyblue", ec="skyblue", bins=10, rwidth=0.80)
plt.xlabel("installment")
plt.ylabel("Frequency ")
plt.legend(legend)
plt.xticks(np.arange(min(installment), max(installment)+64, 64), rotation=60)
plt.title('Frequency of installment of each loans.')
plt.show()

print('Inference:\n\tFrom the \'installment\' column most frequent installment is between 144 to 270 .',
      'But there are clearly some outliers above 98 percentile.')
# Out:
# count    39714.000000
# mean       324.573112
# std        208.877080
# min         15.690000
# 50%        280.230000
# 75%        430.780000
# 80%        483.380000
# 85%        531.000000
# 90%        622.961000
# 95%        763.030500
# 100%      1305.190000
# max       1305.190000
# Name: installment, dtype: float64
# Inference:
# 	From the 'installment' column most frequent installment is between 144 to 270 . But there are clearly some outliers above 98 percentile.

# %% [markdown]
# ##### Analysis of Home Owner Ship variable

# %%
home_ownership = master_frame["home_ownership"].value_counts()

plt.figure(figsize=(15, 15))
plt.subplot(2,2,1)

ax = sns.barplot(x=home_ownership.index, y=home_ownership, palette=sns.color_palette("Blues_r", 4))
show_values_on_bars(ax)
plt.xlabel("Home Ownership")
plt.ylabel("Frequency")
plt.title('Home Ownership vs. Frequency')

# Data's to plot
chart_label_home_ownership = [home_ownership.index[0] + "(" + str(home_ownership.iloc[0]) + ')',
                              home_ownership.index[1] + " (" + str(home_ownership.iloc[1]) + ')',
                              home_ownership.index[2] + " (" + str(home_ownership.iloc[2]) + ')',
                              home_ownership.index[3] + " (" + str(home_ownership.iloc[3]) + ')']

colors = ['gold', 'yellowgreen', 'lightcoral', 'b']
explode = (0, 0, 0, 0.9)  # explode 1st slice

# Plot pie chart
plt.subplot(2,2,2)
plt.pie(home_ownership, explode=explode, labels=chart_label_home_ownership, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=160)
plt.axis('equal')
plt.show()

print('Inference:\n\tPeople who are staying on rented house are taking most of the loans,',
      '\n\tFollowed by people staying in a mortgaged home.')
# Out:
# Inference:
# 	People who are staying on rented house are taking most of the loans,
# 	Followed by people staying in a mortgaged home.

# %% [markdown]
# ##### Analysis of annual income variable

# %%
# Plott the distribution plot for annual_inc to visualise their distribution
print(master_frame['annual_inc'].describe(percentiles=[0, 0.25, 0.50, 0.75, 0.85, 0.90, 0.95, 1]))

# Plotting the distribution plot of annual_inc to visualise their distribution
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(8,5))
master_frame.boxplot(column='annual_inc')
plt.ylabel('Annual income')
plt.legend(legend)
plt.title('Annual income of each loan applicant.')
plt.show()

annual_inc_mode = master_frame['annual_inc'].mode()
print('Inference:\n\tFrom the \'Annual income\' column the mode of Annual income is', annual_inc_mode.values[0],
      '\nSince there are clearly some outliers above 98 percentile this has to be removed.')
# Out:
# count    3.971400e+04
# mean     6.896804e+04
# std      6.379504e+04
# min      4.000000e+03
# 0%       4.000000e+03
# 25%      4.040450e+04
# 50%      5.900000e+04
# 75%      8.229900e+04
# 85%      1.000000e+05
# 90%      1.160000e+05
# 95%      1.420000e+05
# 100%     6.000000e+06
# max      6.000000e+06
# Name: annual_inc, dtype: float64
# Inference:
# 	From the 'Annual income' column the mode of Annual income is 60000.0
# Since there are clearly some outliers above 98 percentile this has to be removed.

# %% [markdown]
# ##### Removing outliers in annual income

# %%
master_frame = master_frame[master_frame.annual_inc <=master_frame.annual_inc.quantile(.98)]
master_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38920 entries, 0 to 39716
# Data columns (total 21 columns):
# loan_amnt              38920 non-null int64
# funded_amnt_inv        38920 non-null float64
# term                   38920 non-null int64
# int_rate               38920 non-null float64
# installment            38920 non-null float64
# sub_grade              38920 non-null object
# emp_length             38920 non-null float64
# home_ownership         38920 non-null object
# annual_inc             38920 non-null float64
# verification_status    38920 non-null object
# issue_d                38920 non-null datetime64[ns]
# loan_status            38920 non-null object
# purpose                38920 non-null object
# zip_code               38920 non-null object
# addr_state             38920 non-null object
# dti                    38920 non-null float64
# delinq_2yrs            38920 non-null int64
# open_acc               38920 non-null int64
# pub_rec                38920 non-null int64
# revol_util             38920 non-null float64
# address                38920 non-null object
# dtypes: datetime64[ns](1), float64(7), int64(5), object(8)
# memory usage: 6.5+ MB

# %% [markdown]
# ##### Plotting annual income after removing outliers

# %%
print(master_frame['annual_inc'].describe(percentiles=[0.75, 0.80, 0.85, 0.90, 0.95, 1]))

# Plotting the distribution plot of installment to visualise their distribution
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.boxplot(y=master_frame['annual_inc'], palette='viridis')
plt.ylabel('annual_inc')
plt.title('annual_inc')

#Frequency Chart
annual_inc = master_frame['annual_inc']
legend = ['annual_inc']
plt.subplot(2,2,2)
plt.hist([annual_inc], color = "skyblue", ec="skyblue", bins=50, rwidth=0.70)
plt.xlabel("annual_inc")
plt.ylabel("Frequency ")
plt.legend(legend)
plt.xticks(np.arange(min(annual_inc), max(annual_inc)+4000, 4000), rotation=60)
plt.title('Frequency of annual_inc of each loans.')
plt.show()

print('Inference:\n\tAfter removing the outliers the \'annual_inc\' column,',
      '\tmost frequent income range is between $46000 to $52000.')
# Out:
# count     38920.000000
# mean      64092.336804
# std       32371.288265
# min        4000.000000
# 50%       58000.000000
# 75%       80000.000000
# 80%       87600.000000
# 85%       96000.000000
# 90%      110000.000000
# 95%      129996.200000
# 100%     187000.000000
# max      187000.000000
# Name: annual_inc, dtype: float64
# Inference:
# 	After removing the outliers the 'annual_inc' column, 	most frequent income range is between $46000 to $52000.

# %% [markdown]
# ##### Analysis of loan status

# %%
#-------------------------------------------------------------------
# The Variable loan_status is an Unordered Categorical
#-------------------------------------------------------------------
loan_status = pd.DataFrame(master_frame['loan_status'].value_counts())

# Data's to plot
chart_label_loan_status = ["Fully Paid (" + str(loan_status.loc['Fully Paid'].values[0]) + ')',
                           "Charged Off (" + str(loan_status.loc['Charged Off'].values[0]) + ')',
                           "Current (" + str(loan_status.loc['Current'].values[0]) + ')']

colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(5, 5))
plt.pie(loan_status, explode=explode, labels=chart_label_loan_status, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

print('Inference: Most of the loans in the data set are fully paid and only a small percentage of loans are current loans.\n')
# Out:
# Inference: Most of the loans in the data set are fully paid and only a small percentage of loans are current loans.

# %% [markdown]
# ##### Univaritate analysis of address(combination of  zipcode and state)

# %%
#Address of borrower(Combination of State and zipcode)
print("Number of unique address to which borrower belong: ",master_frame.address.nunique())

#Frequency Chart 
plt.figure(figsize=(15, 10))
# Restore the rc params from Matplotlib’s internal defaults.
plt.rcdefaults() 
#Plotting top 20 address(State and zip code) based on borrowers whom loan is given
address_values = pd.DataFrame(master_frame['address'].value_counts())[:20]

ax = sns.barplot(x=address_values.index, y="address", data=address_values)
show_values_on_bars(ax)
plt.xlabel("Address")
plt.ylabel("Frequency")
plt.title('Frequency of top 20 address based on number of borrowers')
plt.xticks(rotation=60)
plt.show()
print('Inference:\n\tMaximum number of borrowers are from address NY,100 of loans to whom loans are given\n')
# Out:
# Number of unique address to which borrower belong:  894
# Inference:
# 	Maximum number of borrowers are from address NY,100 of loans to whom loans are given

# %% [markdown]
# # Derived Metrics

# %% [markdown]
# ### Business Driven Metrics :  loan_default_status
# Define a new cloumn loan_default_status which categorises the loan_status into 2 categories "Defaulter"(if loan status is "charged off" and Non-Defaulter if loan status is "Fully Paid" or "Current"

# %%
master_frame['loan_default_status'] = master_frame['loan_status'].apply(lambda x: 'Defaulter' if x == 'Charged Off' else 'Non-Defaulter') 
print('Number of defaulters and Non-Defaulters after merging Current and Fully Paid as Non Defaulter \n',master_frame.groupby('loan_default_status')['loan_default_status'].count(),'\n\n')
master_frame.info()
# Out:
# Number of defaulters and Non-Defaulters after merging Current and Fully Paid as Non Defaulter
#  loan_default_status
# Defaulter         5549
# Non-Defaulter    33371
# Name: loan_default_status, dtype: int64
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38920 entries, 0 to 39716
# Data columns (total 22 columns):
# loan_amnt              38920 non-null int64
# funded_amnt_inv        38920 non-null float64
# term                   38920 non-null int64
# int_rate               38920 non-null float64
# installment            38920 non-null float64
# sub_grade              38920 non-null object
# emp_length             38920 non-null float64
# home_ownership         38920 non-null object
# annual_inc             38920 non-null float64
# verification_status    38920 non-null object
# issue_d                38920 non-null datetime64[ns]
# loan_status            38920 non-null object
# purpose                38920 non-null object
# zip_code               38920 non-null object
# addr_state             38920 non-null object
# dti                    38920 non-null float64
# delinq_2yrs            38920 non-null int64
# open_acc               38920 non-null int64
# pub_rec                38920 non-null int64
# revol_util             38920 non-null float64
# address                38920 non-null object
# loan_default_status    38920 non-null object
# dtypes: datetime64[ns](1), float64(7), int64(5), object(9)
# memory usage: 6.8+ MB

# %% [markdown]
# ### Data Driven Metrics : instal_income_perc
# Define a new cloumn instal_income_perc which is the ratio of installment monthly income(annual_inc/12) multplied by 100

# %%
master_frame['instal_income_perc'] = ((master_frame['installment'])/(master_frame['annual_inc']/12))*100
master_frame.head(10)
# Out:
#    loan_amnt  funded_amnt_inv  term  int_rate  installment sub_grade  \
# 0       5000           4975.0    36     10.65       162.87        B2
# 1       2500           2500.0    60     15.27        59.83        C4
# 2       2400           2400.0    36     15.96        84.33        C5
# 3      10000          10000.0    36     13.49       339.31        C1
# 4       3000           3000.0    60     12.69        67.79        B5
# 5       5000           5000.0    36      7.90       156.46        A4
# 6       7000           7000.0    60     15.96       170.08        C5
# 7       3000           3000.0    36     18.64       109.43        E1
# 8       5600           5600.0    60     21.28       152.39        F2
# 9       5375           5350.0    60     12.69       121.45        B5
#
#    emp_length home_ownership  annual_inc verification_status  \
# 0        10.0           RENT     24000.0            Verified
# 1         0.0           RENT     30000.0     Source Verified
# 2        10.0           RENT     12252.0        Not Verified
# 3        10.0           RENT     49200.0     Source Verified
# 4         1.0           RENT     80000.0     Source Verified
# 5         3.0           RENT     36000.0     Source Verified
# 6         8.0           RENT     47004.0        Not Verified
# 7         9.0           RENT     48000.0     Source Verified
# 8         4.0            OWN     40000.0     Source Verified
# 9         0.0           RENT     15000.0            Verified
#
#           ...         zip_code addr_state    dti delinq_2yrs open_acc  \
# 0         ...              860         AZ  27.65           0        3
# 1         ...              309         GA   1.00           0        3
# 2         ...              606         IL   8.72           0        2
# 3         ...              917         CA  20.00           0       10
# 4         ...              972         OR  17.94           0       15
# 5         ...              852         AZ  11.20           0        9
# 6         ...              280         NC  23.51           0        7
# 7         ...              900         CA   5.35           0        4
# 8         ...              958         CA   5.55           0       11
# 9         ...              774         TX  18.08           0        2
#
#    pub_rec  revol_util  address  loan_default_status  instal_income_perc
# 0        0        83.7   AZ,860        Non-Defaulter            8.143500
# 1        0         9.4   GA,309            Defaulter            2.393200
# 2        0        98.5   IL,606        Non-Defaulter            8.259549
# 3        0        21.0   CA,917        Non-Defaulter            8.275854
# 4        0        53.9   OR,972        Non-Defaulter            1.016850
# 5        0        28.3   AZ,852        Non-Defaulter            5.215333
# 6        0        85.6   NC,280        Non-Defaulter            4.342099
# 7        0        87.5   CA,900        Non-Defaulter            2.735750
# 8        0        32.6   CA,958            Defaulter            4.571700
# 9        0        36.5   TX,774            Defaulter            9.716000
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Type Driven Metrics : interest_rate_bracket
# Define a bracket for interested rate and see how each bracket is performing against loan status

# %%
master_frame['interest_rate_bracket'] = master_frame['int_rate'].apply(lambda x :'0-5' if x <=5 else ('5-10' if x<=10 else ('10-15' if x <=15 else ('15-20' if x<=20 else('20-25' if x <=25 else '25+')))))
master_frame[['int_rate','interest_rate_bracket']].head(10)
# Out:
#    int_rate interest_rate_bracket
# 0     10.65                 10-15
# 1     15.27                 15-20
# 2     15.96                 15-20
# 3     13.49                 10-15
# 4     12.69                 10-15
# 5      7.90                  5-10
# 6     15.96                 15-20
# 7     18.64                 15-20
# 8     21.28                 20-25
# 9     12.69                 10-15

# %% [markdown]
# ### Segmented Univariate Analysis

# %% [markdown]
# ##### Segmented Analysis of state wise loan_status

# %%
#------------------------------------------------------------------------------------------------------------
# The Variable addr_state is an Unordered Categorical 
# lets do a segmented analysis on loan_status using this variable
#------------------------------------------------------------------------------------------------------------

# Rank-frequency plots of unordered categorical variables, when plotted on a log-log scale, 
# typically result in a power law distribution

# Create data
g1 = pd.DataFrame(master_frame[master_frame.loan_default_status == 'Non-Defaulter']['addr_state'].value_counts())
g2 = pd.DataFrame(master_frame[master_frame.loan_default_status == 'Defaulter']['addr_state'].value_counts())
 
data = (g1, g2)
colors = ("green", "blue")
groups = ("Non-Defaulter", "Defaulter") 
 
# Create plot
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(1, 1, 1, facecolor="1.0")

for data, color, group in zip(data, colors, groups):
    x = data.index
    y = data.addr_state
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)
    
plt.title('State wise loan application distribution')
plt.legend(loc=1)
plt.xticks(rotation=45)
plt.show()

# Which state has most of the loan application ?
print('Inference:\n \tThe state CA has most of the loans...')

# Which state code has most of the 'Fully Paid' loan application status?
print('\tThe state CA has most of the \'Non-Defaulted\' loans...')

# Which state code has most of the Charged Off loan application status?
print('\tThe state CA has most of the \'Defaulted\' loans...')

print('Conclusion: State CA tops in both Non-Defaulter and Defaulter catagories of loans.\n')
# Out:
# Inference:
#  	The state CA has most of the loans...
# 	The state CA has most of the 'Non-Defaulted' loans...
# 	The state CA has most of the 'Defaulted' loans...
# Conclusion: State CA tops in both Non-Defaulter and Defaulter catagories of loans.

# %% [markdown]
# ##### Segmented analysis of Zip Code wise loan_status of state CA

# %%
#-------------------------------------------------------------------
# The Variable zip_code is an Unordered Categorical variable
#-------------------------------------------------------------------

# Rank-frequency plots of unordered categorical variables, when plotted on a log-log scale, 
# typically result in a power law distribution

# Create data
CA_df = pd.DataFrame(master_frame[master_frame.addr_state == 'CA'])

g1 = pd.DataFrame(CA_df[CA_df.loan_default_status == 'Non-Defaulter']['zip_code'].value_counts())
g2 = pd.DataFrame(CA_df[CA_df.loan_default_status == 'Defaulter']['zip_code'].value_counts())
 
data = (g1, g2)
colors = ("green", "blue")
groups = ("Non-Defaulter", "Defaulter") 
 
# Create plot
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
fig = plt.figure(figsize=(21, 6))
ax = fig.add_subplot(1, 1, 1, facecolor="1.0")

for data, color, group in zip(data, colors, groups):
    x = data.index
    y = data.zip_code
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)
    
plt.title('zip code wise loan application distribution of State CA')
plt.legend(loc=1)
plt.xticks(rotation=45)
plt.show()


#Which zip code in CA has most of the loan applicaitons?
print('Inference:\n \tThe zip code \'945\' in state CA has most of the loans...')

#Which zip code in CA has most of the loan applicaitons status as Fully Paid?
print('\tThe zip code \'945\' in state CA has most of the Non-Defaulted loans...')

#Which zip code in CA has most of the loan applicaitons status as Charged Off?
print('\tThe zip code \'945\' in state CA has most of the Defaulted loans...')

print('Conclusion: zip code \'945\' at State CA tops in Non-Defaulter and Defaulter catagories of loans.\n')
# Out:
# Inference:
#  	The zip code '945' in state CA has most of the loans...
# 	The zip code '945' in state CA has most of the Non-Defaulted loans...
# 	The zip code '945' in state CA has most of the Defaulted loans...
# Conclusion: zip code '945' at State CA tops in Non-Defaulter and Defaulter catagories of loans.

# %% [markdown]
# ###### Segmented analysis based on loan status for loan amount, funded amount and interest rate.

# %%
plt.rcdefaults()
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.boxplot(x="loan_default_status", y="loan_amnt", data=master_frame)

plt.subplot(2, 2, 2)
sns.boxplot(x="loan_default_status",  y="funded_amnt_inv", data=master_frame)

plt.subplot(2, 2, 3)
sns.boxplot(x="loan_default_status", y="int_rate", data=master_frame)\

plt.subplot(2, 2, 4)
sns.boxplot(x="loan_default_status", y="term", data=master_frame)

plt.show()


print('Inference:\n \t The loan_amnt and funded_amnt_inv has almost equal spread and median for defaulted and non-defaulted loans...\n')

print('\t The interest rate bracket for defaulted loans is clearly higher than non-defaulted loans...\n')

print('\tAlmost All the loans Defaulted are given for 60 months interval...\n')

print('Conclusion: 60 months term loans and higher interest loans have maximum chances of defaulting')
# Out:
# Inference:
#  	 The loan_amnt and funded_amnt_inv has almost equal spread and median for defaulted and non-defaulted loans...
#
# 	 The interest rate bracket for defaulted loans is clearly higher than non-defaulted loans...
#
# 	Almost All the loans Defaulted are given for 60 months interval...
#
# Conclusion: 60 months term loans and higher interest loans have maximum chances of defaulting

# %% [markdown]
# ###### Segmented univariate for instal_income_perc for each loan_default_status

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.

plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.boxplot(x="loan_default_status", y="instal_income_perc", data=master_frame)


plt.show()


print('Inference:\n \t The installment to income perc is slightly higher for defaulted loans than non-defaulted loans...\n')
# Out:
# Inference:
#  	 The installment to income perc is slightly higher for defaulted loans than non-defaulted loans...

# %% [markdown]
# ##### Segmented Analysis of sub grade

# %%
#Frequency Chart
sub_grade_fp = master_frame[master_frame.loan_default_status == 'Non-Defaulter'].sub_grade
sub_grade_co = master_frame[master_frame.loan_default_status == 'Defaulter'].sub_grade

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(10,5))

plt.hist([sub_grade_fp], bins=100, rwidth=0.80)
plt.hist([sub_grade_co], bins=100, rwidth=0.80)

plt.xlabel("sub_grade")
plt.ylabel("Frequency ")

plt.legend(master_frame.loan_default_status)
plt.xticks(rotation=60)

plt.title('Sub Grade Frequency of Non-Defaulted and Defaulted loans')

plt.show()

print('Inference:\n\tLower the sub-grade higher is the chances of defaulting.. ')
# Out:
# Inference:
# 	Lower the sub-grade higher is the chances of defaulting..

# %% [markdown]
# ##### Segmented univariate for interest_rate_bracket for each loan_default_status

# %%
print("Get the percentage of defaults for each of  the loan brackets\n")
loan_stat_per_interest_bracket = pd.crosstab(master_frame['interest_rate_bracket'],master_frame['loan_default_status']).apply(lambda r: round((r/r.sum()*100),2), axis=1)
print(loan_stat_per_interest_bracket);

print("\nInference: Nearly 35% of loans in the interest bracket 20-25% have been defaulted followed by 15-20% interest bracket which has defaulted loan of 24%\n")\

#Frequency Chart
emp_length_fp = master_frame[master_frame.loan_default_status == 'Non-Defaulter']['interest_rate_bracket']
emp_length_co = master_frame[master_frame.loan_default_status == 'Defaulter'].interest_rate_bracket

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(10, 5))

plt.hist([emp_length_fp], bins=10, rwidth=0.80, color='lightblue')
plt.hist([emp_length_co], bins=10, rwidth=0.80, color='mediumseagreen')

plt.xlabel("interest_rate_bracket")
plt.ylabel("Frequency ")

plt.legend(master_frame.loan_default_status, loc='upper right')

plt.title('interest_rate_bracket Frequency of Non-Defaulted and Defaulted loans')

plt.show()
# Out:
# Get the percentage of defaults for each of  the loan brackets
#
# loan_default_status    Defaulter  Non-Defaulter
# interest_rate_bracket
# 10-15                      14.54          85.46
# 15-20                      23.63          76.37
# 20-25                      34.59          65.41
# 5-10                        6.73          93.27
#
# Inference: Nearly 35% of loans in the interest bracket 20-25% have been defaulted followed by 15-20% interest bracket which has defaulted loan of 24%

# %% [markdown]
# ##### Segmented analysis of employment length

# %%
#Frequency Chart
emp_length_fp = master_frame[master_frame.loan_default_status == 'Non-Defaulter']['emp_length']
emp_length_co = master_frame[master_frame.loan_default_status == 'Defaulter'].emp_length

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(10, 5))

plt.hist([emp_length_fp], bins=10, rwidth=0.80, color='lightblue')
plt.hist([emp_length_co], bins=10, rwidth=0.80, color='mediumseagreen')

plt.xlabel("emp_length")
plt.ylabel("Frequency ")

plt.legend(master_frame.loan_default_status, loc='upper left')
plt.xticks(np.arange(min(emp_length_co), max(emp_length_co)+1, 1), rotation=60)
plt.title('Employment length Frequency of Non-Defaulted and Defaulted loans')

plt.show()

print('Inference:\n\t Lower experience employees tend to default more on loan payment than high experience employees..')
# Out:
# Inference:
# 	 Lower experience employees tend to default more on loan payment than high experience employees..

# %% [markdown]
# ###### Segmented Analysis of Verification status

# %%
print("Get the percentage of defaults for each of  the verification status category\n")
loan_stat_for_verification = pd.crosstab(master_frame['verification_status'],master_frame['loan_default_status']).apply(lambda r: round((r/r.sum()*100),2), axis=1)
print(loan_stat_for_verification)



print('Verification statuses unique values ', master_frame.verification_status.unique())
verification_status_fp = master_frame[master_frame.loan_default_status == 'Non-Defaulter'].verification_status
verification_status_co = master_frame[master_frame.loan_default_status == 'Defaulter'].verification_status

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(10,5))

plt.hist([verification_status_fp], bins=verification_status_fp.nunique(), rwidth=0.97, color='turquoise')
plt.hist([verification_status_co], bins=verification_status_co.nunique(), rwidth=0.97, color='teal')

plt.xlabel("Verification status")
plt.ylabel("Frequency ")

plt.legend(master_frame.loan_default_status)
plt.xticks()

plt.title('Verification status of Non-Defaulted and Defaulted loans')

plt.show()


print('Inference:\n\t Maxiumum percentage(16%) of loans sanctioned in "Verified" category have been defaulted in loan while Not Verified have the least(12%)')
# Out:
# Get the percentage of defaults for each of  the verification status category
#
# loan_default_status  Defaulter  Non-Defaulter
# verification_status
# Not Verified             12.66          87.34
# Source Verified          14.50          85.50
# Verified                 16.23          83.77
# Verification statuses unique values  ['Verified' 'Source Verified' 'Not Verified']
# Inference:
# 	 Maxiumum percentage(16%) of loans sanctioned in "Verified" category have been defaulted in loan while Not Verified have the least(12%)

# %% [markdown]
# ###### Segmented analysis of term

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.

fp = master_frame[master_frame.term == 36].loan_default_status
co = master_frame[master_frame.term == 60].loan_default_status

plt.hist([fp], bins=fp.nunique()+2, color='cadetblue')
plt.hist([co], bins=co.nunique()+2, color='lightcoral')

plt.xlabel("Loan status")
plt.ylabel("Frequency")

plt.legend(master_frame.term)
plt.xticks()

plt.title('loan status of 36 and 60 months terms')
plt.show()

print('Inference:\n\tThe defaulted loans has mostly 60 months term.')
# Out:
# Inference:
# 	The defaulted loans has mostly 60 months term.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Bivariate  Correlation metrics for all the quantitative fields

# %%
#Bivariate Coorelation Matrix
corr = round(master_frame.corr(),2)

corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col0 {
#             background-color:  #023858;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col1 {
#             background-color:  #03476f;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col2 {
#             background-color:  #adc1dd;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col3 {
#             background-color:  #c0c9e2;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col4 {
#             background-color:  #034a74;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col5 {
#             background-color:  #e1dfed;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col6 {
#             background-color:  #549cc7;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col7 {
#             background-color:  #e4e1ef;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col8 {
#             background-color:  #fef6fa;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col9 {
#             background-color:  #d2d3e7;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col10 {
#             background-color:  #fff7fb;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col11 {
#             background-color:  #e7e3f0;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow0_col12 {
#             background-color:  #2786bb;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col0 {
#             background-color:  #03476f;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col1 {
#             background-color:  #023858;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col2 {
#             background-color:  #adc1dd;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col3 {
#             background-color:  #c0c9e2;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col4 {
#             background-color:  #045280;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col5 {
#             background-color:  #dfddec;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col6 {
#             background-color:  #60a1ca;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col7 {
#             background-color:  #e1dfed;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col8 {
#             background-color:  #fef6fa;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col9 {
#             background-color:  #d5d5e8;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col10 {
#             background-color:  #fff7fb;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col11 {
#             background-color:  #e6e2ef;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow1_col12 {
#             background-color:  #2d8abd;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col0 {
#             background-color:  #a1bbda;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col1 {
#             background-color:  #a1bbda;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col2 {
#             background-color:  #023858;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col3 {
#             background-color:  #88b1d4;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col4 {
#             background-color:  #eae6f1;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col5 {
#             background-color:  #eae6f1;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col6 {
#             background-color:  #bdc8e1;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col7 {
#             background-color:  #e4e1ef;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col8 {
#             background-color:  #f7f0f7;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col9 {
#             background-color:  #ece7f2;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col10 {
#             background-color:  #f7f0f7;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col11 {
#             background-color:  #e7e3f0;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow2_col12 {
#             background-color:  #cccfe5;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col0 {
#             background-color:  #b4c4df;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col1 {
#             background-color:  #b4c4df;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col2 {
#             background-color:  #8bb2d4;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col3 {
#             background-color:  #023858;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col4 {
#             background-color:  #bdc8e1;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col5 {
#             background-color:  #faf2f8;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col6 {
#             background-color:  #c0c9e2;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col7 {
#             background-color:  #dedcec;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col8 {
#             background-color:  #dbdaeb;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col9 {
#             background-color:  #f2ecf5;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col10 {
#             background-color:  #e8e4f0;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col11 {
#             background-color:  #6da6cd;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow3_col12 {
#             background-color:  #9fbad9;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col0 {
#             background-color:  #034a74;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col1 {
#             background-color:  #045280;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col2 {
#             background-color:  #f1ebf5;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col3 {
#             background-color:  #c6cce3;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col4 {
#             background-color:  #023858;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col5 {
#             background-color:  #e7e3f0;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col6 {
#             background-color:  #589ec8;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col7 {
#             background-color:  #e6e2ef;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col8 {
#             background-color:  #fbf3f9;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col9 {
#             background-color:  #d2d3e7;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col10 {
#             background-color:  #fef6fa;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col11 {
#             background-color:  #e1dfed;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow4_col12 {
#             background-color:  #167bb6;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col0 {
#             background-color:  #dedcec;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col1 {
#             background-color:  #dbdaeb;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col2 {
#             background-color:  #f0eaf4;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col3 {
#             background-color:  #fef6fa;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col4 {
#             background-color:  #e6e2ef;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col5 {
#             background-color:  #023858;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col6 {
#             background-color:  #a2bcda;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col7 {
#             background-color:  #e7e3f0;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col8 {
#             background-color:  #f7f0f7;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col9 {
#             background-color:  #e1dfed;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col10 {
#             background-color:  #f0eaf4;
#         }    #T_09ff961a_9337_11e8_95c1_8c85901b732frow5_col11

# %%
print("\n There are no strong correlation observed between different fields except for loan_amount, installment and funded_amnt_inv which is expected and obvious..")
# Out:
#  There are no strong correlation observed between different fields except for loan_amount, installment and funded_amnt_inv which is expected and obvious..

# %% [markdown]
# ## Bivariate analysis on continuous variables

# %%
# Create 2 data frame one for Non-Defaulter and another for Defaulter
fully_paid_df = pd.DataFrame(master_frame[master_frame.loan_default_status == 'Non-Defaulter']).reset_index()
charged_off_df = pd.DataFrame(master_frame[master_frame.loan_default_status == 'Defaulter']).reset_index()

# %% [markdown]
# ##### Correlation of Loan amount and funded amount of Defaulted loans

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20, 25))

loan_fund_amnt = pd.DataFrame({'loan_amnt': charged_off_df['loan_amnt'], 'funded_amnt_inv': charged_off_df['funded_amnt_inv']})
corrcoefficiant = pearsonr(loan_fund_amnt['loan_amnt'], loan_fund_amnt['funded_amnt_inv'])
print("The correlation of loan amount and funded amount is ",
      round(corrcoefficiant[0], 2))

print("\nLine plot showing loan amnt and funded amnt from invester.\n")
loan_fund_amnt.plot(kind='line', subplots=False)
plt.title('Correlation between loan amount and funded amount')
plt.show()

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

print("\nCorrelation plot of loan amount and funded amount.\n")
corr = loan_fund_amnt.corr()
print(corr)
corr.plot(kind='line', subplots=False)
plt.show()

print('The loan amont and funded amount has higher corelation coeffeciant in the case of Defaulted loans.')
# Out:
# The correlation of loan amount and funded amount is  0.91
#
# Line plot showing loan amnt and funded amnt from invester.
# Correlation plot of loan amount and funded amount.
#
#                  loan_amnt  funded_amnt_inv
# loan_amnt         1.000000         0.907442
# funded_amnt_inv   0.907442         1.000000
# The loan amont and funded amount has higher corelation coeffeciant in the case of Defaulted loans.

# %% [markdown]
# ##### Correlation of Loan amount and funded amount of Non-Defaulted loans

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(20, 25))

loan_fund_amnt = pd.DataFrame({'loan_amnt': fully_paid_df['loan_amnt'], 'funded_amnt_inv': fully_paid_df['funded_amnt_inv']})
corrcoefficiant = pearsonr(loan_fund_amnt['loan_amnt'], loan_fund_amnt['funded_amnt_inv'])
print("The correlation of loan amount and funded amount is ",
      round(corrcoefficiant[0], 2))

print("\nLine plot showing loan amnt and funded amnt from invester.\n")
loan_fund_amnt.plot(kind='line', subplots=False)
plt.title('Correlation between loan amount and funded amount')
plt.show()

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

print("\nCorrelation plot of loan amount and funded amount.\n")
corr = loan_fund_amnt.corr()
print(corr)
corr.plot(kind='line', subplots=False)
plt.show()

print('The loan amont and funded amount has higher corelation coeffeciant in the case of Non-Defaulted loans.')
# Out:
# The correlation of loan amount and funded amount is  0.95
#
# Line plot showing loan amnt and funded amnt from invester.
# Correlation plot of loan amount and funded amount.
#
#                  loan_amnt  funded_amnt_inv
# loan_amnt         1.000000         0.946416
# funded_amnt_inv   0.946416         1.000000
# The loan amont and funded amount has higher corelation coeffeciant in the case of Non-Defaulted loans.

# %% [markdown]
# ## Bivariate analysis on categorical variables

# %% [markdown]
# ##### Analysis of year and loan status

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.

issue_d_fp = fully_paid_df.groupby(fully_paid_df.issue_d.dt.year).size()
issue_d_co = charged_off_df.groupby(charged_off_df.issue_d.dt.year).size()

ind = np.arange(max(len(issue_d_fp), len(issue_d_co)))  # the x locations for the groups
width = 0.35       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(ind-width,issue_d_fp,width,color='cadetblue',label='Non-Defaulter')
ax.bar(ind,issue_d_co,width,color='lightcoral',label='Defaulter')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels( (issue_d_fp.index) )
show_values_on_bars(ax)
plt.xlabel('Years')
plt.ylabel('Number of loans')
plt.title('Year wise loan status')
plt.legend()

plt.show()

print('Inference:\n\tYear 2011 has most loans on both catagories.')
# Out:
# Inference:
# 	Year 2011 has most loans on both catagories.

# %% [markdown]
# ###### Analysis of Verification Status and Loan Status

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.

verification_status_fp = fully_paid_df.groupby(fully_paid_df.verification_status).size()
verification_status_co = charged_off_df.groupby(charged_off_df.verification_status).size()

ind = np.arange(max(len(verification_status_fp), len(verification_status_co)))  # the x locations for the groups
width = 0.35       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(ind-width, verification_status_fp, width, color='cadetblue', label='Non-Defaulter')
ax.bar(ind, verification_status_co, width, color='lightcoral', label='Defaulter')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels( (verification_status_fp.index) )
show_values_on_bars(ax)
plt.xlabel('Verification status')
plt.ylabel('Number of loans')
plt.title('Verification status for both loan status')
plt.legend()

plt.show()

# %% [markdown]
# ##### Analysis of Sub Grade and loan status

# %%
# grouby(grade,loan_status) take average  of loan_amount

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(200,25))

g1 = fully_paid_df.groupby(fully_paid_df.sub_grade).loan_amnt.mean()
g2 = charged_off_df.groupby(charged_off_df.sub_grade).loan_amnt.mean()

xlabel = 'Sub grade'
ylabel = 'Mean of loan amount'
title = 'Sub grade for both loan status'

ind = np.arange(max(len(g1), len(g2)))  # the x locations for the groups
width = 0.35       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

ax.bar(ind-width, g1, width, color='blue', label='Non-Defaulter')
ax.bar(ind, g2, width, color='gold', label='Defaulter')

ax.set_xticks(ind + width / 2)
ax.set_xticklabels( (g1.index) )

plt.xticks(rotation=60)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.legend()

plt.show()

print('Inference:\n\tLower the grade higher is the average loan amount and risk for defaulting except for few exceptions')
# Out:
# Inference:
# 	Lower the grade higher is the average loan amount and risk for defaulting except for few exceptions

# %% [markdown]
# ###### Analysis of Employment duration and loan status

# %%
# grouby(emp_length,loan_status) take average  of loan_amount

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(200,25))

g1 = round(fully_paid_df.groupby(fully_paid_df.emp_length).size())
g2 = round(charged_off_df.groupby(charged_off_df.emp_length).size())

xlabel = 'emp length'
ylabel = 'Number of loans'
title = 'emp length for both loan status'

ind = np.arange(max(len(g1), len(g2)))  # the x locations for the groups
width = 0.35       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

ax.bar(ind-width, g1, width, color='cadetblue', label='Non-Defaulter')
ax.bar(ind, g2, width, color='gold', label='Defaulter')

ax.set_xticks(ind + width / 2)
ax.set_xticklabels( (g1.index) )

plt.xticks(rotation=60)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.legend()

plt.show()

print('Inference:\n\tEmployees with longer duration are processing more loans in both catagories')
print('\tThere is no much deviation in defaulting rate based on employees’ experience.')
# Out:
# Inference:
# 	Employees with longer duration are processing more loans in both catagories
# 	There is no much deviation in defaulting rate based on employees’ experience.

# %% [markdown]
# ###### Analysis of state, purpose and loan status

# %%
# Groupby(State, purpose, loan_status) : Take count of loan_status

# Create pivot table first
charged_off_df["purpose"] = charged_off_df["purpose"].astype("category")
charged_off_pvt_df = pd.pivot_table(charged_off_df, index=["purpose"], values="loan_status", columns="addr_state", aggfunc=[len])
charged_off_pvt_df.columns = charged_off_pvt_df.columns.droplevel(0)
charged_off_pvt_df
# Out:
# addr_state           AK    AL   AR    AZ     CA    CO    CT   DC   DE     FL  \
# purpose
# car                 NaN   1.0  3.0   4.0   26.0   2.0   3.0  NaN  NaN   16.0
# credit_card         3.0   7.0  2.0  17.0  138.0   9.0  10.0  4.0  3.0   44.0
# debt_consolidation  7.0  25.0  9.0  55.0  546.0  53.0  50.0  7.0  2.0  232.0
# educational         NaN   1.0  1.0   3.0   10.0   2.0   NaN  NaN  NaN    9.0
# home_improvement    NaN   6.0  2.0   2.0   57.0   6.0   9.0  NaN  NaN   38.0
# house               NaN   NaN  NaN   2.0   14.0   1.0   1.0  NaN  NaN    7.0
# major_purchase      NaN   3.0  NaN   6.0   34.0   2.0   5.0  NaN  NaN   30.0
# medical             1.0   1.0  1.0   1.0   17.0   1.0   1.0  NaN  NaN    9.0
# moving              NaN   1.0  NaN   2.0   23.0   NaN   NaN  1.0  NaN    4.0
# other               NaN   5.0  5.0  12.0  117.0  11.0   7.0  2.0  4.0   46.0
# renewable_energy    NaN   NaN  NaN   1.0    1.0   NaN   NaN  NaN  NaN    2.0
# small_business      2.0   3.0  2.0  12.0   86.0   8.0   7.0  1.0  3.0   49.0
# vacation            1.0   NaN  1.0   NaN   14.0   1.0   1.0  NaN  NaN    1.0
# wedding             NaN   1.0  NaN   3.0   25.0   1.0   NaN  NaN  NaN    9.0
#
# addr_state         ...    SD   TN     TX    UT    VA   VT    WA    WI   WV  \
# purpose            ...
# car                ...   NaN  NaN   11.0   1.0   4.0  NaN   4.0   1.0  NaN
# credit_card        ...   3.0  1.0   25.0   3.0  11.0  1.0  17.0   8.0  3.0
# debt_consolidation ...   6.0  1.0  135.0  15.0  90.0  5.0  66.0  33.0  9.0
# educational        ...   NaN  NaN    5.0   2.0   1.0  NaN   NaN   NaN  NaN
# home_improvement   ...   NaN  NaN   18.0   2.0  12.0  NaN   3.0   2.0  1.0
# house              ...   NaN  NaN    4.0   NaN   1.0  NaN   NaN   1.0  1.0
# major_purchase     ...   NaN  NaN   17.0   NaN   3.0  NaN   4.0   3.0  1.0
# medical            ...   NaN  NaN    6.0   NaN   4.0  NaN   3.0   1.0  1.0
# moving             ...   NaN  NaN    2.0   NaN   NaN  NaN   2.0   NaN  NaN
# other              ...   2.0  NaN   47.0   6.0  25.0  NaN  15.0   7.0  3.0
# renewable_energy   ...   NaN  NaN    2.0   1.0   2.0  NaN   NaN   NaN  NaN
# small_business     ...   1.0  NaN   29.0   8.0  15.0  NaN  11.0   5.0  2.0
# vacation           ...   NaN  NaN    2.0   1.0   3.0  NaN   1.0   1.0  NaN
# wedding            ...   NaN  NaN    4.0   NaN   5.0  NaN   1.0   NaN  NaN
#
# addr_state           WY
# purpose
# car                 NaN
# credit_card         1.0
# debt_consolidation  1.0
# educational         NaN
# home_improvement    1.0
# house               NaN
# major_purchase      NaN
# medical             NaN
# moving              NaN
# other               NaN
# renewable_energy    NaN
# small_business      1.0
# vacation            NaN
# wedding             NaN
#
# [14 rows x 47 columns]

# %%
# Second pivot table
fully_paid_df["purpose"] = fully_paid_df["purpose"].astype("category")
fully_paid_pvt_df = pd.pivot_table(fully_paid_df, index=["purpose"], values="loan_status", columns="addr_state", aggfunc=[len])
fully_paid_pvt_df.columns = fully_paid_pvt_df.columns.droplevel(0)
fully_paid_pvt_df
# Out:
# addr_state            AK     AL    AR     AZ      CA     CO     CT     DC  \
# purpose
# car                  1.0   21.0  14.0   31.0   199.0   28.0   30.0    4.0
# credit_card          8.0   42.0  26.0  110.0   894.0  119.0   75.0   37.0
# debt_consolidation  26.0  199.0  95.0  304.0  2859.0  324.0  290.0  104.0
# educational          NaN    3.0   1.0    4.0    34.0    7.0    4.0    NaN
# home_improvement    10.0   34.0  21.0   63.0   316.0   35.0   56.0    9.0
# house                NaN    6.0   1.0   10.0    48.0   11.0    5.0    2.0
# major_purchase       3.0   26.0  21.0   45.0   282.0   34.0   44.0    8.0
# medical              2.0    3.0   5.0   18.0   114.0   16.0    8.0    1.0
# moving               NaN    3.0   NaN   17.0    85.0   13.0    8.0    4.0
# other                6.0   31.0  17.0   77.0   567.0   45.0   60.0   12.0
# renewable_energy     NaN    1.0   NaN    2.0    17.0    3.0    3.0    NaN
# small_business       7.0   20.0   9.0   39.0   220.0   33.0   21.0    4.0
# vacation             NaN    2.0   2.0    5.0    70.0    4.0    6.0    6.0
# wedding              1.0    4.0   1.0   16.0   143.0    9.0   17.0    6.0
#
# addr_state            DE      FL  ...     SD   TN      TX     UT     VA    VT  \
# purpose                           ...
# car                  5.0    98.0  ...    2.0  1.0   105.0   11.0   57.0   1.0
# credit_card         11.0   291.0  ...   10.0  2.0   345.0   35.0  161.0   6.0
# debt_consolidation  42.0  1023.0  ...   22.0  3.0  1023.0  104.0  592.0  22.0
# educational          NaN    19.0  ...    NaN  1.0    11.0    2.0    5.0   NaN
# home_improvement    15.0   207.0  ...    3.0  1.0   191.0   17.0   97.0   3.0
# house                1.0    37.0  ...    1.0  NaN    15.0    2.0   12.0   NaN
# major_purchase       5.0   142.0  ...    2.0  2.0   143.0    5.0   61.0   4.0
# medical              1.0    40.0  ...    NaN  NaN    56.0    9.0   11.0   1.0
# moving               2.0    39.0  ...    NaN  NaN    29.0    1.0   21.0   1.0
# other                9.0   246.0  ...    7.0  3.0   236.0   11.0   99.0   6.0
# renewable_energy     NaN     7.0  ...    NaN  NaN     8.0    NaN    2.0   NaN
# small_business       3.0    91.0  ...    4.0  2.0   108.0   13.0   45.0   4.0
# vacation             2.0    21.0  ...    NaN  NaN    18.0    3.0   11.0   NaN
# wedding              4.0    58.0  ...    1.0  NaN    64.0    1.0   32.0   NaN
#
# addr_state             WA     WI    WV    WY
# purpose
# car                  28.0   22.0   8.0   4.0
# credit_card         101.0   66.0  19.0   7.0
# debt_consolidation  331.0  173.0  85.0  36.0
# educational           7.0    2.0   NaN   NaN
# home_improvement     52.0   34.0   8.0   3.0
# house                 6.0    5.0   NaN   1.0
# major_purchase       34.0   23.0  12.0  13.0
# medical              11.0    3.0   2.0   2.0
# moving                6.0    5.0   2.0   NaN
# other                64.0   28.0  12.0  11.0
# renewable_energy      2.0    NaN   NaN   NaN
# small_business       36.0   20.0   3.0   1.0
# vacation             12.0    4.0   5.0   NaN
# wedding              10.0    5.0   NaN   1.0
#
# [14 rows x 50 columns]

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(16,8))
sns.boxplot(data=fully_paid_pvt_df, showfliers=False, palette="Set3")
plt.xticks(rotation=60)
plt.legend(fully_paid_pvt_df.index)
plt.show()

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(16,8))
ax = sns.boxplot(data=charged_off_pvt_df, showfliers=False, palette="Set3")
plt.xticks(rotation=60)
plt.legend(charged_off_pvt_df.index, loc=1)
plt.show()

# The loan taken for debt consolidation has highest chances of defaulting
# The state CA has highest percentage of defaulters
print('Inference:\n\tThe loan taken for debt consolidation has highest chances of defaulting')
print('\tThe state CA has highest percentage of defaulters')
# Out:
# Inference:
# 	The loan taken for debt consolidation has highest chances of defaulting
# 	The state CA has highest percentage of defaulters

# %% [markdown]
# ###### Analysis of home owner and loan status

# %%
#print("Get the percentage of defaults for each of  the verification status category\n")
#loan_stat_for_home_ownership = pd.crosstab(master_frame['home_ownership'],master_frame['loan_default_status']).apply(lambda r: round((r/r.sum()*100),2), axis=1)
#print(loan_stat_for_home_ownership)

plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(200,25))

g1 = round(fully_paid_df.groupby(fully_paid_df.home_ownership).size())
g2 = round(charged_off_df.groupby(charged_off_df.home_ownership).size())

xlabel = 'home ownership'
ylabel = 'Number of loans'
title = 'home ownership for both loan status'

ind = np.arange(max(len(g1), len(g2)))  # the x locations for the groups
width = 0.35       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)

ax.bar(ind-width, g1, width, color='cadetblue', label='Non-Defaulter')
ax.bar(ind, g2, width, color='gold', label='Defaulter')

ax.set_xticks(ind + width / 2)
ax.set_xticklabels( (g1.index) )

plt.xticks(rotation=60)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.legend()

plt.show()

print('Inference:\n\tApplicant who are in rental homes are more likely to default followed by mortgaged home owners.')
# Out:
# Inference:
# 	Applicant who are in rental homes are more likely to default followed by mortgaged home owners.

# %% [markdown]
# ###### Analysis of address, verification status, home ownership and loan status

# %%
not_verified = charged_off_df.loc[fully_paid_df.verification_status == 'Not Verified']
rent = pd.DataFrame(not_verified[not_verified.home_ownership == 'RENT'])
g1 = pd.DataFrame(rent.addr_state.value_counts())
# Plot year wise bar chart of issue_d column 
draw_bar_chart(g1, g1.index, "addr_state", 20, 20,
               'State wise count of defaulted loan applicant is staying on rental',
               'State', 'Frequency', None,
               'Inference: The State CA has maximum number of defaulted loan applicant staying on rental.',
              True)
# Out:
# Inference: The State CA has maximum number of defaulted loan applicant staying on rental.

# %% [markdown]
# ###### Analysis of verification status and loan status based on annual income

# %%
# Groupby(verification status,loan_status) : Take average of annual_inc

# Create pivot table first
charged_off_pvt_df = pd.pivot_table(charged_off_df, index=["verification_status"], values="annual_inc", columns="loan_default_status", aggfunc=[np.mean])
charged_off_pvt_df.columns = charged_off_pvt_df.columns.droplevel(0)
charged_off_pvt_df
# Out:
# loan_default_status     Defaulter
# verification_status
# Not Verified         52635.181697
# Source Verified      57112.503800
# Verified             66787.825280

# %%
# Inference:
# in each of the verification_status group(Not verified,source verified,verified), Fully paid always has higher average annual_inc than charged off
fully_paid_pvt_df = pd.pivot_table(fully_paid_df, index=["verification_status"], values="annual_inc", columns="loan_default_status", aggfunc=[np.mean])
fully_paid_pvt_df.columns = fully_paid_pvt_df.columns.droplevel(0)
fully_paid_pvt_df
# Out:
# loan_default_status  Non-Defaulter
# verification_status
# Not Verified          58669.808540
# Source Verified       63014.910050
# Verified              75343.250518

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(8,8))

plt.subplot(2, 2, 1)
sns.boxplot(data=charged_off_pvt_df, showfliers=False, palette="Set3")

plt.subplot(2, 2, 2)
sns.boxplot(data=fully_paid_pvt_df, showfliers=False, palette="Set3")

plt.xticks()
plt.show()

# %%
loan_status_pvt_df = pd.pivot_table(master_frame, index=["interest_rate_bracket"], values="instal_income_perc", columns=["loan_default_status","term"], aggfunc=[np.median])
loan_status_pvt_df.columns = loan_status_pvt_df.columns.droplevel(0)
print("\nInference from below table:\n\t For each term term loan the installment to income ration of for each of the interest slabs  are as below.\n\t This influences whether a loan is likely to be defaulted or not:\n")
loan_status_pvt_df
# Out:
# Inference from below table:
# 	 For each term term loan the installment to income ration of for each of the interest slabs  are as below.
# 	 This influences whether a loan is likely to be defaulted or not:
# loan_default_status   Defaulter           Non-Defaulter
# term                         36        60            36        60
# interest_rate_bracket
# 10-15                  6.594200  6.645357      6.132338  5.800984
# 15-20                  7.258667  7.203643      7.100320  6.657143
# 20-25                  9.570312  9.347769      7.218121  8.037000
# 5-10                   5.415128  4.921428      4.951257  3.875707

# %%
plt.rcdefaults() # Restore the rc params from Matplotlib’s internal defaults.
plt.figure(figsize=(24,8))

plt.subplot(2, 2, 1)
sns.boxplot(data=loan_status_pvt_df, showfliers=False, palette="Set3")
plt.show()
